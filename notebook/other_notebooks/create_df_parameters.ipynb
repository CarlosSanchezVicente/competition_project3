# %%
# Imports
import pandas as pd

# %% [markdown]
# ## Dataframe with parameters

# %%
data = {
    'Model': ['Voting model', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF', 'RF'],
    'cv_score':   [534.5, 563.6, 563.1, 568.2, 578.5, 570.0, 569.6, 570.3, 570.3, 570.2, 569.5, 573.2, 574.2, 570.1,
                  570.1, 568.2, 571.1, 570.9, 567.5, 569.9, 570.4, 569.6, 575.9, 556.6, 571.0, 578.4, 568.7, 1193.7],
    'rmse':       [529.8, 541.8, 541.9, 545.7, 552.8, 552.9, 553.1, 553.2, 553.3, 553.4, 553.6, 553.7, 554.4, 554.7,
                  554.7, 555.2, 555.2, 555.6, 555.7, 556.4, 556.0, 556.1, 558.2, None, 562.8, 563.1, 587.9, 1176.9],
    'Submission': [538, 597, 597, 0, 552, 543, 0, 0, 0, 0, 0, 0, 0, 542, 542, 0, 0, 0, 0, 0, 0, 0, 0, 541, 0, 0, 0, 0],
    'Features': [
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price', 'shape'],
        ['cut', 'color', 'clarity', 'city', 'depth', 'table', 'carat_log', 'x_log', 'y_log', 'z_log', 'ratio_length_width', 'ratio_length_width_depth', 'volume', 'density', 'price'],
        ['cut', 'color', 'clarity', 'city', 'depth', 'table', 'carat_log', 'x_log', 'y_log', 'z_log', 'ratio_length_width', 'ratio_length_width_depth', 'volume', 'density', 'price'],
        ['cut', 'color', 'clarity', 'city', 'depth', 'table','x', 'y', 'z', 'carat_log',  'ratio_length_width', 'ratio_length_width_depth', 'volume', 'density', 'price'],
        ['cut', 'color', 'clarity', 'carat_log', 'depth', 'table', 'price'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price'],
        ['cut', 'color', 'clarity', 'city', 'depth', 'table', 'x', 'y', 'z', 'carat_log', 'price'],
        ['cut', 'color', 'clarity', 'city', 'depth', 'table', 'x', 'y', 'z', 'carat_log', 'price'],
        ['cut', 'color', 'clarity', 'city', 'depth', 'table', 'x', 'y', 'z', 'carat_log', 'price'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price', 'shape'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price', 'shape'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'table','x', 'y', 'z', 'carat_log', 'price'],
        ['cut', 'color', 'clarity', 'city', 'carat_log', 'table','x', 'y', 'z', 'price'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'x', 'y', 'z','avg_girdle', 'table_mm', 'xyz', 'price'],
        ['cut', 'color', 'clarity', 'carat_log', 'table','x', 'y', 'z', 'price'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'x', 'y', 'z', 'table_mm', 'price'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'x', 'y', 'z', 'avg_girdle', 'table_mm', 'price'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price', 'shape'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price', 'shape'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'avg_girdle', 'table_mm', 'xyz', 'price'],
        ['cut', 'color', 'clarity', 'city', 'carat_log', 'depth', 'table','x_log', 'y_log', 'z_log', 'price'],
        ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price'],
        ['color', 'carat', 'table', 'x', 'y', 'z', 'price']  
    ],
    
    'Transformations': [
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'imputation', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
        ['encoding'],
        ['encoding', 'drop_zeros', 'remove_outliers', 'remove_duplicates'],
    ],
    
    'Estimators': [
        ['lgbm', 'xgb', 'extrees', 'rf'],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
        [None],
    ],
    
    'Hyperparameters': [{},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},  
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 600, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 300, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 1500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 400, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 50, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 100, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 5, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 1500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False},
                        {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}]
}

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#           Model  cv_score   rmse  Submission  \
# 0  Voting model     534.5  529.8         538
# 1            RF     563.6  541.8         597
# 2            RF     563.1  541.9         597
# 3            RF     568.2  545.7           0
# 4            RF     578.5  552.8         552
#
#                                             Features  \
# 0  [cut, color, clarity, city, carat, depth, tabl...
# 1  [cut, color, clarity, city, depth, table, cara...
# 2  [cut, color, clarity, city, depth, table, cara...
# 3  [cut, color, clarity, city, depth, table, x, y...
# 4  [cut, color, clarity, carat_log, depth, table,...
#
#                                      Transformations  \
# 0  [encoding, drop_zeros, remove_outliers, remove...
# 1  [encoding, drop_zeros, remove_outliers, remove...
# 2  [encoding, drop_zeros, remove_outliers, remove...
# 3  [encoding, drop_zeros, remove_outliers, remove...
# 4  [encoding, imputation, remove_outliers, remove...
#
# ...

# %%
df.to_csv('./parameters_training/best_parameters_prediction_models.csv', index=False)

# %% [markdown]
# ## Parameters model

# %%
# Model = Voting model | estimators = [('lgbm', lgb_model), ('xgb', xgb_model), ('extrees', extrees_model), ('rf', rf_model),] 
# Features = ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price', 'shape']
# encoding, drop_zeros, remove_outliers y remove_duplicates
# Submission = 538 -----------------------------------------------------------------
voting_model = VotingRegressor(estimators=estimators, n_jobs =-1, verbose = False)
Hyperparameters:  {'estimators': [('lgbm', LGBMRegressor(learning_rate=0.01, n_estimators=3000, num_leaves=20, random_state=0)), ('xgb', XGBRegressor(base_score=None, booster=None, callbacks=None,
             colsample_bylevel=None, colsample_bynode=None,
             colsample_bytree=None, device=None, early_stopping_rounds=None,
             enable_categorical=False, eval_metric=None, feature_types=None,
             gamma=None, grow_policy=None, importance_type=None,
             interaction_constraints=None, learning_rate=None, max_bin=None,
             max_cat_threshold=None, max_cat_to_onehot=None,
             max_delta_step=None, max_depth=None, max_features='sqrt',
             max_leaves=None, min_child_weight=None, min_samples_split=2,
             missing=nan, monotone_constraints=None, multi_strategy=None,
             n_estimators=100, n_jobs=None, ...)), ('extrees', ExtraTreesRegressor(n_estimators=1000, random_state=0)), ('rf', RandomForestRegressor(max_features=None, n_estimators=500, n_jobs=-1,
                      random_state=42))], 'n_jobs': -1, 'verbose': False, 'weights': None, 'lgbm': LGBMRegressor(learning_rate=0.01, n_estimators=3000, num_leaves=20,
              random_state=0), 'xgb': XGBRegressor(base_score=None, booster=None, callbacks=None,
             colsample_bylevel=None, colsample_bynode=None,
             colsample_bytree=None, device=None, early_stopping_rounds=None,
             enable_categorical=False, eval_metric=None, feature_types=None,
             gamma=None, grow_policy=None, importance_type=None,
             interaction_constraints=None, learning_rate=None, max_bin=None,
             max_cat_threshold=None, max_cat_to_onehot=None,
             max_delta_step=None, max_depth=None, max_features='sqrt',
             max_leaves=None, min_child_weight=None, min_samples_split=2,
             missing=nan, monotone_constraints=None, multi_strategy=None,
             n_estimators=100, n_jobs=None, ...), 'extrees': ExtraTreesRegressor(n_estimators=1000, random_state=0), 'rf': RandomForestRegressor(max_features=None, n_estimators=500, n_jobs=-1,
                      random_state=42), 'lgbm__boosting_type': 'gbdt', 'lgbm__class_weight': None, 'lgbm__colsample_bytree': 1.0, 'lgbm__importance_type': 'split', 'lgbm__learning_rate': 0.01, 'lgbm__max_depth': -1, 'lgbm__min_child_samples': 20, 'lgbm__min_child_weight': 0.001, 'lgbm__min_split_gain': 0.0, 'lgbm__n_estimators': 3000, 'lgbm__n_jobs': None, 'lgbm__num_leaves': 20, 'lgbm__objective': None, 'lgbm__random_state': 0, 'lgbm__reg_alpha': 0.0, 'lgbm__reg_lambda': 0.0, 'lgbm__subsample': 1.0, 'lgbm__subsample_for_bin': 200000, 'lgbm__subsample_freq': 0, 'xgb__objective': 'reg:squarederror', 'xgb__base_score': None, 'xgb__booster': None, 'xgb__callbacks': None, 'xgb__colsample_bylevel': None, 'xgb__colsample_bynode': None, 'xgb__colsample_bytree': None, 'xgb__device': None, 'xgb__early_stopping_rounds': None, 'xgb__enable_categorical': False, 'xgb__eval_metric': None, 'xgb__feature_types': None, 'xgb__gamma': None, 'xgb__grow_policy': None, 'xgb__importance_type': None, 'xgb__interaction_constraints': None, 'xgb__learning_rate': None, 'xgb__max_bin': None, 'xgb__max_cat_threshold': None, 'xgb__max_cat_to_onehot': None, 'xgb__max_delta_step': None, 'xgb__max_depth': None, 'xgb__max_leaves': None, 'xgb__min_child_weight': None, 'xgb__missing': nan, 'xgb__monotone_constraints': None, 'xgb__multi_strategy': None, 'xgb__n_estimators': 100, 'xgb__n_jobs': None, 'xgb__num_parallel_tree': None, 'xgb__random_state': 0, 'xgb__reg_alpha': None, 'xgb__reg_lambda': None, 'xgb__sampling_method': None, 'xgb__scale_pos_weight': None, 'xgb__subsample': None, 'xgb__tree_method': None, 'xgb__validate_parameters': None, 'xgb__verbosity': None, 'xgb__max_features': 'sqrt', 'xgb__min_samples_split': 2, 'extrees__bootstrap': False, 'extrees__ccp_alpha': 0.0, 'extrees__criterion': 'squared_error', 'extrees__max_depth': None, 'extrees__max_features': 1.0, 'extrees__max_leaf_nodes': None, 'extrees__max_samples': None, 'extrees__min_impurity_decrease': 0.0, 'extrees__min_samples_leaf': 1, 'extrees__min_samples_split': 2, 'extrees__min_weight_fraction_leaf': 0.0, 'extrees__monotonic_cst': None, 'extrees__n_estimators': 1000, 'extrees__n_jobs': None, 'extrees__oob_score': False, 'extrees__random_state': 0, 'extrees__verbose': 0, 'extrees__warm_start': False, 'rf__bootstrap': True, 'rf__ccp_alpha': 0.0, 'rf__criterion': 'squared_error', 'rf__max_depth': None, 'rf__max_features': None, 'rf__max_leaf_nodes': None, 'rf__max_samples': None, 'rf__min_impurity_decrease': 0.0, 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 2, 'rf__min_weight_fraction_leaf': 0.0, 'rf__monotonic_cst': None, 'rf__n_estimators': 500, 'rf__n_jobs': -1, 'rf__oob_score': False, 'rf__random_state': 42, 'rf__verbose': 0, 'rf__warm_start': False}  
    | cv_score_mean: 534.5149881270156  | rmse: 529.8787996711075
CPU times: total: 2min 50s
Wall time: 13min 31s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'depth', 'table', 'carat_log', 'x_log', 'y_log', 'z_log',
#             'ratio_length_width', 'ratio_length_width_depth', 'volume', 'density', 'price']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=500 
# Submission = 597 -----------------------------------------------------------------
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 563.6224504060208  | rmse: 541.8872683394235
CPU times: total: 17min 7s
Wall time: 2min 22s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'depth', 'table', 'carat_log', 
#             'ratio_length_width', 'ratio_length_width_depth', 'volume', 'density', 'price']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=500
# Submission = 597 -----------------------------------------------------------------
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 563.1380099851094  | rmse: 541.9037907071685
CPU times: total: 14min 32s
Wall time: 1min 56s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'depth', 'table','x', 'y', 'z', 'carat_log', 
#             'ratio_length_width', 'ratio_length_width_depth', 'volume', 'density', 'price']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=500 
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 568.2830813092132  | rmse: 545.7160325766089
CPU times: total: 18min 18s
Wall time: 2min 32s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'carat_log', 'depth', 'table', 'price']
# encoding, imputation, remove_outliers y remove_duplicates | n_stimators=500
# Submission = 552 -----------------------------------------------------------------
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 578.5952143324417  | rmse: 552.891156245962
CPU times: total: 4min 37s
Wall time: 40.2 s

# Model = RF
# Features de serie, encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=500
# Submission = 543---------------------------------------------------------------
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 570.0212938830194  | rmse: 552.9419513838835  | rmse_2: 552.9419513838835
CPU times: total: 9min 28s
Wall time: 1min 22s -23

# Model = RF
# Features de serie, encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=600
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 600, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 569.6888950649824  | rmse: 553.1880851479532  | rmse_2: 553.1880851479532
CPU times: total: 11min 53s
Wall time: 1min 40s

# Model = RF
# Features de serie, encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=400
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 300, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 570.392820611711  | rmse: 553.2600932696147  | rmse_2: 553.2600932696147
CPU times: total: 4min 35s
Wall time: 42.8 s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'depth', 'table', 'x', 'y', 'z', 'carat_log', 'price']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=500 
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 570.336771427553  | rmse: 553.3567161129744
CPU times: total: 9min 54s
Wall time: 1min 32s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'depth', 'table', 'x', 'y', 'z', 'carat_log', 'price']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=500 
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 570.2595671275265  | rmse: 553.4054287603929
CPU times: total: 9min 10s
Wall time: 1min 14s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'depth', 'table', 'x', 'y', 'z', 'carat_log', 'price']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=1500 
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 1500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 569.5750376223212  | rmse: 553.6604440230118
CPU times: total: 31min 48s
Wall time: 4min 27s

# Model = RF
# Features de serie, encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=400
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 573.2463024252991  | rmse: 553.7944242193641  | rmse_2: 553.7944242193641
CPU times: total: 1min 27s
Wall time: 13.4 s

# Model = RF
# Features de serie, encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=400
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 574.2712643507491  | rmse: 554.488321315124  | rmse_2: 554.488321315124
CPU times: total: 1min 23s
Wall time: 13.1 s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price', 'shape']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=500
# Submission = 542 ----------------------------------------------------------
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 570.1513571076711  | rmse: 554.7242488195719
CPU times: total: 10min 2s
Wall time: 1min 25s -15
    
# Model = RF   
# Features = ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price', 'shape']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=500
# Submission = 542 ----------------------------------------------------------
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 570.1513571076711  | rmse: 554.7242488195719
CPU times: total: 9min 52s
Wall time: 1min 20s
    
# Model = RF
# Features de serie, encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=400
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 400, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 568.2230549678686  | rmse: 555.2393808873512  | rmse_2: 555.2393808873512
CPU times: total: 15min 42s
Wall time: 2min 12s
    
# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'carat', 'table','x', 'y', 'z', 'carat_log', 'price'] 
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=500 
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 571.09845582581  | rmse: 555.2875203635209  | rmse_2: 555.2875203635209
CPU times: total: 8min 40s
Wall time: 1min 11s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'carat_log', 'table','x', 'y', 'z', 'price']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=50
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 570.9756633240581  | rmse: 555.6053281565353  | rmse_2: 555.6053281565353
CPU times: total: 8min 43s
Wall time: 1min 15s
    
# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'x', 'y', 'z','avg_girdle', 'table_mm', 'xyz', 'price'] 
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=500   
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 567.5032514631432  | rmse: 555.7750839709606  | rmse_2: 555.7750839709606
CPU times: total: 14min 5s
Wall time: 1min 53s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'carat_log', 'table','x', 'y', 'z', 'price']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=50
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 569.945980050026  | rmse: 556.4799516795906  | rmse_2: 556.4799516795906
CPU times: total: 6min 35s
Wall time: 55 s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'x', 'y', 'z', 'table_mm', 'price']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=50
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 570.4899544500876  | rmse: 556.0081586081567  | rmse_2: 556.0081586081567
CPU times: total: 10min 40s
Wall time: 1min 30s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'x', 'y', 'z', 'avg_girdle', 'table_mm', 'price']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=50
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 569.6400678426654  | rmse: 556.1522654109002  | rmse_2: 556.1522654109002
CPU times: total: 12min 2s
Wall time: 1min 44s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price', 'shape']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=50
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 50, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 575.92611795982  | rmse: 558.2782585570247
CPU times: total: 44.2 s
Wall time: 7.55 s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price', 'shape']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=1500
# Submision = 541 ---------------------------------------------------------------
{'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 100, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 5, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 1500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
| cv_score_mean: 556.6704984876692
CPU times: total: 1h 17s
Wall time: 8min 11s

# Model = RF
# Features = [['cut', 'color', 'clarity', 'city', 'carat', 'depth', 'avg_girdle', 'table_mm', 'xyz', 'price']] 
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=500 
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 571.0132381609183  | rmse: 562.8086785378399  | rmse_2: 562.8086785378399
CPU times: total: 10min 44s
Wall time: 1min 26s

# Model = RF
# Features = ['cut', 'color', 'clarity', 'city', 'carat_log', 'depth', 'table','x_log', 'y_log', 'z_log', 'price']
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=500 
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 578.4665781312609  | rmse: 563.1005194121811
CPU times: total: 7min 48s
Wall time: 1min 7s
    
# Model = RF
# Features de serie y solo encoding | n_stimators=400
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 568.7680257934356  | rmse: 587.9591159724442  | rmse_2: 587.9591159724442
CPU times: total: 1min 2s
Wall time: 1min 3s
    
# Model = RF
# Features = ['color', 'carat', 'table', 'x', 'y', 'z', 'price'] 
# encoding, drop_zeros, remove_outliers y remove_duplicates | n_stimators=500
Hyperparameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}  
    | cv_score_mean: 1193.7263388731408  | rmse: 1176.9075341911703  | rmse_2: 1176.9075341911703
CPU times: total: 6min 9s
Wall time: 53.4 s
